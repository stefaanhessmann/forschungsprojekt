# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import os
from scipy.spatial.distance import squareform, cdist
import time

path_to_files = "./../Dataset/c7o2h10_md/c7o2h10_md/"
filenames = os.listdir(path_to_files)
print('number of files: {}'.format(len(filenames)))
energy_file, traj_file = filenames[:2]
# Out:
# number of files: 226

# %%
energy_file = './../Dataset/c7o2h10_md/c7o2h10_equilibrium.dat'
filepath = os.path.join(path_to_files, energy_file)
df_energy = pd.read_csv(filepath, header=0, dtype=dict(energy=float))

# %%
df_energy.head(10)
# Out:
#    #ElectrEnergy[eV]
# 0      -11504.031870
# 1      -11503.940429
# 2      -11503.705678
# 3      -11503.525822
# 4      -11503.433154
# 5      -11503.304322
# 6      -11503.074781
# 7      -11502.794584
# 8      -11502.585769
# 9      -11502.561856

# %%
filepath = os.path.join(path_to_files, traj_file)
df_energy = pd.read_csv(filepath, header=0, dtype=dict(energy=float))

# %%
df_energy
# Out:
#                                                        19
# 0                                        Iteration:     1
# 1        C         1.480339         0.135466        -0...
# 2        C         0.028364         0.057259         0...
# 3        C        -1.172214        -0.009417         0...
# 4        C        -2.636647        -0.060517         0...
# 5        O        -3.222266         1.231753        -0...
# 6        C        -3.152095        -1.017031        -0...
# 7        O        -4.466970        -1.529764        -0...
# 8        C        -3.362972        -2.443660        -0...
# 9        C        -3.276936        -3.496477        -1...
# 10       H         1.943404        -0.496934         0...
# 11       H         1.856394        -0.192277        -1...
# 12       H         1.828021         1.161256         0...
# 13       H        -2.987078        -0.428885         1...
# 14       H        -2.769228         1.679953        -0...
# ...
